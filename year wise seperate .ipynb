# %%
import pandas as pd
import numpy as np

# %%
#2023-24
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Download the punkt tokenizer
nltk.download('punkt')

# Download the VADER lexicon
nltk.download('vader_lexicon')

# Sample text from the budget plan
text = """
Moreover, the Union Budget 2023 increased subsidies for electric vehicles, encouraging their adoption.

Previously, electric two-wheelers were eligible for a subsidy of up to Rs 15,000 per kWh of battery capacity, or 40% of the total cost, whichever was lower

Electric Vehicle Ecosystem
68. Our Government will expand and strengthen the e-vehicle
ecosystem by supporting manufacturing and charging
infrastructure. Greater adoption of e-buses for public transport
networks will be encouraged through payment security
mechanism.

Strengthening e-vehicle ecosystem by supporting
manufacturing and charging
"""

# Tokenize the text into sentences
sentences = nltk.sent_tokenize(text)

# Initialize Vader sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Analyze sentiment for each sentence
for sentence in sentences:
    print(sentence)
    scores = sid.polarity_scores(sentence)
    print("Sentiment Score:", scores)
    print()
# Out:
# Moreover, the Union Budget 2023 increased subsidies for electric vehicles, encouraging their adoption.
# Sentiment Score: {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.6705}
#
# Previously, electric two-wheelers were eligible for a subsidy of up to Rs 15,000 per kWh of battery capacity, or 40% of the total cost, whichever was lower
#
# Electric Vehicle Ecosystem
# 68.
# Sentiment Score: {'neg': 0.071, 'neu': 0.929, 'pos': 0.0, 'compound': -0.296}
#
# Our Government will expand and strengthen the e-vehicle
# ecosystem by supporting manufacturing and charging
# infrastructure.
# Sentiment Score: {'neg': 0.0, 'neu': 0.615, 'pos': 0.385, 'compound': 0.7579}
#
# Greater adoption of e-buses for public transport
# networks will be encouraged through payment security
# mechanism.
# Sentiment Score: {'neg': 0.0, 'neu': 0.619, 'pos': 0.381, 'compound': 0.7506}
#
# Strengthening e-vehicle ecosystem by supporting
# manufacturing and charging
# Sentiment Score: {'neg': 0.0, 'neu': 0.496, 'pos': 0.504, 'compound': 0.7269}
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
#2022-23
text = """
We will promote a shift to use of public transport in urban areas. This will be complemented by clean tech and governance solutions, special mobility zones with zero fossil-fuel policy, and EV vehicles.

To further provide impetus to green mobility, customs duty exemption 
is being extended to import of capital goods and machinery required for 
manufacture of lithium-ion cells for batteries used in electric vehicles. 

 The budget extends battery subsidies for another year
 
 The duty on lithium batteries is lowered from 21% to 13%
 
 The budget allocates Rs 51.72 billion (about USD 631 million) for this program
Production-linked incentive (PLI): The budget allocation for this scheme is raised from Rs 483.77 crore in 2023-24 to Rs 3,500 crore in 2024-25

"""

# Tokenize the text into sentences
sentences = nltk.sent_tokenize(text)

# Initialize Vader sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Analyze sentiment for each sentence
for sentence in sentences:
    print(sentence)
    scores = sid.polarity_scores(sentence)
    print("Sentiment Score:", scores)
    print()
# Out:
# We will promote a shift to use of public transport in urban areas.
# Sentiment Score: {'neg': 0.0, 'neu': 0.809, 'pos': 0.191, 'compound': 0.3818}
#
# This will be complemented by clean tech and governance solutions, special mobility zones with zero fossil-fuel policy, and EV vehicles.
# Sentiment Score: {'neg': 0.0, 'neu': 0.705, 'pos': 0.295, 'compound': 0.7269}
#
# To further provide impetus to green mobility, customs duty exemption
# is being extended to import of capital goods and machinery required for
# manufacture of lithium-ion cells for batteries used in electric vehicles.
# Sentiment Score: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# The budget extends battery subsidies for another year
#
#  The duty on lithium batteries is lowered from 21% to 13%
#
#  The budget allocates Rs 51.72 billion (about USD 631 million) for this program
# Production-linked incentive (PLI): The budget allocation for this scheme is raised from Rs 483.77 crore in 2023-24 to Rs 3,500 crore in 2024-25
# Sentiment Score: {'neg': 0.026, 'neu': 0.904, 'pos': 0.07, 'compound': 0.3612}

# %%
#2021-22
text = """

The Government has all along been promoting the 
replacement of conventional fuel-propelled private cars (PCs) with
electric vehicles (EVs).

In the past ten years, the number of EVs increased from 184 to over 
18 500, with the total number of electric private cars (e-PCs) 
accounting for 2.7 per cent of the total number of PCs.

Under Make in India initiative, well laid out customs duty rates were 
pre-announced for items like mobile phones, electric vehicles and their 
components. This has ensured gradual increase in domestic value addition 
capacity in India.

 Customs duty rates are being revised on electric vehicles, 
and parts of mobiles as part of such carefully conceived Phased 
Manufacturing Plans.

Under Make in India initiative, well laid out customs duty rates were 
pre-announced for items like mobile phones, electric vehicles and their 
components.

This has ensured gradual increase in domestic value addition 
capacity in India. Customs duty rates are being revised on electric vehicles, 
and parts of mobiles as part of such carefully conceived Phased 
Manufacturing Plans.
"""

# Tokenize the text into sentences
sentences = nltk.sent_tokenize(text)

# Initialize Vader sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Analyze sentiment for each sentence
for sentence in sentences:
    print(sentence)
    scores = sid.polarity_scores(sentence)
    print("Sentiment Score:", scores)
    print()
# Out:
# The Government has all along been promoting the
# replacement of conventional fuel-propelled private cars (PCs) with
# electric vehicles (EVs).
# Sentiment Score: {'neg': 0.0, 'neu': 0.878, 'pos': 0.122, 'compound': 0.3612}
#
# In the past ten years, the number of EVs increased from 184 to over
# 18 500, with the total number of electric private cars (e-PCs)
# accounting for 2.7 per cent of the total number of PCs.
# Sentiment Score: {'neg': 0.0, 'neu': 0.842, 'pos': 0.158, 'compound': 0.4588}
#
# Under Make in India initiative, well laid out customs duty rates were
# pre-announced for items like mobile phones, electric vehicles and their
# components.
# Sentiment Score: {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.5574}
#
# This has ensured gradual increase in domestic value addition
# capacity in India.
# Sentiment Score: {'neg': 0.0, 'neu': 0.68, 'pos': 0.32, 'compound': 0.5719}
#
# Customs duty rates are being revised on electric vehicles,
# and parts of mobiles as part of such carefully conceived Phased
# Manufacturing Plans.
# Sentiment Score: {'neg': 0.0, 'neu': 0.933, 'pos': 0.067, 'compound': 0.128}
#
# Under Make in India initiative, well laid out customs duty rates were
# pre-announced for items like mobile phones, electric vehicles and their
# components.
# Sentiment Score: {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.5574}
#
# This has ensured gradual increase in domestic value addition
# capacity in India.
# Sentiment Score: {'neg': 0.0, 'neu': 0.68, 'pos': 0.32, 'compound': 0.5719}
#
# Customs duty rates are being revised on electric vehicles,
# and parts of mobiles as part of such carefully conceived Phased
# Manufacturing Plans.
# Sentiment Score: {'neg': 0.0, 'neu': 0.933, 'pos': 0.067, 'compound': 0.128}

# %%
#2020-21

text="""
. Under Make in India initiative, well laid out customs duty rates were
pre-announced for items like mobile phones, electric vehicles and their
components.

 This has ensured gradual increase in domestic value addition
capacity in India. Customs duty rates are being revised on electric vehicles,
and parts of mobiles as part of such carefully conceived Phased
Manufacturing Plans.


Government has already moved GST council to lower the GST rate on electric vehicles from 12% to 5%. 

Also to make EVs affordable to consumers, our government will provide additional income tax deduction of INR 1.5 lakh on the interest paid on loans taken to purchase electric vehicles
 
instead of focusing on how many electric vehicles are being sold, the focus should really be on how many trips or how many kilometres out of every 100, are electric or ecofriendly.




"""


# Tokenize the text into sentences
sentences = nltk.sent_tokenize(text)

# Initialize Vader sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Analyze sentiment for each sentence
for sentence in sentences:
    print(sentence)
    scores = sid.polarity_scores(sentence)
    print("Sentiment Score:", scores)
    print()
# Out:
# .
# Sentiment Score: {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
#
# Under Make in India initiative, well laid out customs duty rates were
# pre-announced for items like mobile phones, electric vehicles and their
# components.
# Sentiment Score: {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.5574}
#
# This has ensured gradual increase in domestic value addition
# capacity in India.
# Sentiment Score: {'neg': 0.0, 'neu': 0.68, 'pos': 0.32, 'compound': 0.5719}
#
# Customs duty rates are being revised on electric vehicles,
# and parts of mobiles as part of such carefully conceived Phased
# Manufacturing Plans.
# Sentiment Score: {'neg': 0.0, 'neu': 0.933, 'pos': 0.067, 'compound': 0.128}
#
# Government has already moved GST council to lower the GST rate on electric vehicles from 12% to 5%.
# Sentiment Score: {'neg': 0.115, 'neu': 0.885, 'pos': 0.0, 'compound': -0.296}
#
# Also to make EVs affordable to consumers, our government will provide additional income tax deduction of INR 1.5 lakh on the interest paid on loans taken to purchase electric vehicles
#
# instead of focusing on how many electric vehicles are being sold, the focus should really be on how many trips or how many kilometres out of every 100, are electric or ecofriendly.
# Sentiment Score: {'neg': 0.0, 'neu': 0.953, 'pos': 0.047, 'compound': 0.4588}

# %%
#2019-2020

text="""
 Phase-II of FAME Scheme, following approval of the Cabinet with
an outlay of 10,000 crore for a period of 3 years, has commenced from
1st April, 2019.

 The main objective of the Scheme is to encourage faster
adoption of Electric vehicles by way of offering upfront incentive on
purchase of Electric vehicles and also by establishing the necessary
charging infrastructure for electric vehicles.

Only advanced battery and
registered e-vehicles will be incentivized under the Scheme with greater
emphasis on providing affordable & environment friendly public
transportation options for the common man.

In order to boost economic growth and Make in India, the
government will launch a scheme to invite global companies through a
transparent competitive bidding to set up mega-manufacturing plants in
sunrise and advanced technology areas such as Semi-conductor
Fabrication (FAB), Solar Photo Voltaic cells, Lithium storage batteries,
Solar electric charging infrastructure, Computer Servers, Laptops, etc.
and provide them investment linked income tax exemptions under
section 35 AD of the Income Tax Act, and other indirect tax benefits.

 Considering our large consumer base, we aim to leapfrog and
envision India as a global hub of manufacturing of Electric Vehicles.

 Inclusion of Solar storage batteries and charging infrastructure in the
above scheme will boost our efforts.

 Government has already moved GST
council to lower the GST rate on electric vehicles from 12% to 5%. Also to
make electric vehicle affordable to consumers, our government will
provide additional income tax deduction of 1.5 lakh on the interest paid
on loans taken to purchase electric vehicles.


 This amounts to a benefit of
around 2.5 lakh over the loan period to the taxpayers who take loans
to purchase electric vehicle.

 Incentive to purchase electric vehicle: In order to incentivise
purchase of electric vehicle by an individual, it is proposed to
provide deduction of an amount uptoRs. 1,50,000 for interest paid
on loan taken for purchase of electric vehicle.









"""




# Tokenize the text into sentences
sentences = nltk.sent_tokenize(text)

# Initialize Vader sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Analyze sentiment for each sentence
for sentence in sentences:
    print(sentence)
    scores = sid.polarity_scores(sentence)
    print("Sentiment Score:", scores)
    print()
# Out:
#  Phase-II of FAME Scheme, following approval of the Cabinet with
# an outlay of 10,000 crore for a period of 3 years, has commenced from
# 1st April, 2019.
# Sentiment Score: {'neg': 0.0, 'neu': 0.774, 'pos': 0.226, 'compound': 0.7739}
#
# The main objective of the Scheme is to encourage faster
# adoption of Electric vehicles by way of offering upfront incentive on
# purchase of Electric vehicles and also by establishing the necessary
# charging infrastructure for electric vehicles.
# Sentiment Score: {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'compound': 0.7003}
#
# Only advanced battery and
# registered e-vehicles will be incentivized under the Scheme with greater
# emphasis on providing affordable & environment friendly public
# transportation options for the common man.
# Sentiment Score: {'neg': 0.0, 'neu': 0.757, 'pos': 0.243, 'compound': 0.7717}
#
# In order to boost economic growth and Make in India, the
# government will launch a scheme to invite global companies through a
# transparent competitive bidding to set up mega-manufacturing plants in
# sunrise and advanced technology areas such as Semi-conductor
# Fabrication (FAB), Solar Photo Voltaic cells, Lithium storage batteries,
# Solar electric charging infrastructure, Computer Servers, Laptops, etc.
# Sentiment Score: {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'compound': 0.8225}
#
# and provide them investment linked income tax exemptions under
# section 35 AD of the Income Tax Act, and other indirect tax benefits.
# Sentiment Score: {'neg': 0.0, 'neu': 0.89, 'pos': 0.11, 'compound': 0.3818}
#
# Considering our large consumer base, we aim to leapfrog and
# envision India as a global hub of manufacturing of Electric Vehicles.
# Sentiment Score: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Inclusion of Solar storage batteries and charging infrastructure in the
# above scheme will boost our efforts.
# Sentiment Score: {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'compound': 0.4019}
#
# Government has already moved GST
# council to lower the GST rate on electric vehicles from 12% to 5%.
# Sentiment Score: {'neg': 0.115, 'neu': 0.885, 'pos': 0.0, 'compound': -0.296}
#
# Also to
# make electric vehicle affordable to consumers, our government will
# provide additional income tax deduction of 1.5 lakh on the interest paid
# on loans taken to purchase electric vehicles.
# Sentiment Score: {'neg': 0.0, 'neu': 0.906, 'pos': 0.094, 'compound': 0.4588}
#
# This amounts to a benefit of
# around 2.5 lakh over the loan period to the taxpayers who take loans
# to purchase electric vehicle.
# Sentiment Score: {'neg': 0.0, 'neu': 0.875, 'pos': 0.125, 'compound': 0.4588}
#
# Incentive to purchase electric vehicle: In order to incentivise
# purchase of electric vehicle by an individual, it is proposed to
# provide deduction of an amount uptoRs.
# Sentiment Score: {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.3612}
#
# 1,50,000 for interest paid
# on loan taken for purchase of electric vehicle.
# Sentiment Score: {'neg': 0.0, 'neu': 0.786, 'pos': 0.214, 'compound': 0.4588}

# %%
# Initialize an empty DataFrame to store sentiment scores
sentiment_scores_df = pd.DataFrame(columns=['Sentence', 'Compound Score', 'Negative Score', 'Neutral Score', 'Positive Score'])

# Analyze sentiment for each sentence and store the scores in the DataFrame
for sentence in sentences:
    scores = sid.polarity_scores(sentence)
    sentiment_scores_df = sentiment_scores_df.append({'Sentence': sentence, 'Compound Score': scores['compound'], 
                                                      'Negative Score': scores['neg'], 'Neutral Score': scores['neu'], 
                                                      'Positive Score': scores['pos']}, ignore_index=True)

# Export the DataFrame to an Excel file
sentiment_scores_df.to_excel('sentiment_scores.xlsx', index=False, encoding='utf-8-sig')

# Display the DataFrame
print(sentiment_scores_df)
# Out:
#                                              Sentence  Compound Score  \
# 0   \n Phase-II of FAME Scheme, following approval...          0.7739
# 1   The main objective of the Scheme is to encoura...          0.7003
# 2   Only advanced battery and\nregistered e-vehicl...          0.7717
# 3   In order to boost economic growth and Make in ...          0.8225
# 4   and provide them investment linked income tax ...          0.3818
# 5   Considering our large consumer base, we aim to...          0.0000
# 6   Inclusion of Solar storage batteries and charg...          0.4019
# 7   Government has already moved GST\ncouncil to l...         -0.2960
# 8   Also to\nmake electric vehicle affordable to c...          0.4588
# 9   This amounts to a benefit of\naround 2.5 lakh ...          0.4588
# 10  Incentive to purchase electric vehicle: In ord...          0.3612
# 11  1,50,000 for interest paid\non loan taken for ...          0.4588
#
#     Negative Score  Neutral Score  Positive Score
# 0            0.000          0.774           0.226
# 1            0.000          0.854           0.146
# 2            0.000          0.757           0.243
# 3            0.000          0.822           0.178
# 4            0.000          0.890           0.110
# 5            0.000          1.000           0.000
# 6            0.000          0.847           0.153
# 7            0.115          0.885           0.000
# 8            0.000          0.906           0.094
# 9            0.000          0.875           0.125
# 10           0.000          0.909           0.091
# 11           0.000          0.786           0.214
# C:\Users\hp\AppData\Local\Temp\ipykernel_10612\733496169.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentiment_scores_df = sentiment_scores_df.append({'Sentence': sentence, 'Compound Score': scores['compound'],
# C:\Users\hp\AppData\Local\Temp\ipykernel_10612\733496169.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentiment_scores_df = sentiment_scores_df.append({'Sentence': sentence, 'Compound Score': scores['compound'],
# C:\Users\hp\AppData\Local\Temp\ipykernel_10612\733496169.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentiment_scores_df = sentiment_scores_df.append({'Sentence': sentence, 'Compound Score': scores['compound'],
# C:\Users\hp\AppData\Local\Temp\ipykernel_10612\733496169.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentiment_scores_df = sentiment_scores_df.append({'Sentence': sentence, 'Compound Score': scores['compound'],
# C:\Users\hp\AppData\Local\Temp\ipykernel_10612\733496169.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentiment_scores_df = sentiment_scores_df.append({'Sentence': sentence, 'Compound Score': scores['compound'],
# C:\Users\hp\AppData\Local\Temp\ipykernel_10612\733496169.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentiment_scores_df = sentiment_scores_df.append({'Sentence': sentence, 'Compound Score': scores['compound'],
# C:\Users\hp\AppData\Local\Temp\ipykernel_10612\733496169.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentiment_scores_df = sentiment_scores_df.append({'Sentence': sentence, 'Compound Score': scores['compound'],
# C:\Users\hp\AppData\Local\Temp\ipykernel_10612\733496169.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentiment_scores_df = sentiment_scores_df.append({'Sentence': sentence, 'Compound Score': scores['compound'],
# C:\Users\hp\AppData\Local\Temp\ipykernel_10612\733496169.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentiment_scores_df = sentiment_scores_df.append({'Sentence': sentence, 'Compound Score': scores['compound'],
# C:\Users\hp\AppData\Local\Temp\ipykernel_10612\733496169.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentiment_scores_df = sentiment_scores_df.append({'Sentence': sentence, 'Compound Score': scores['compound'],
# C:\Users\hp\AppData\Local\Temp\ipykernel_10612\733496169.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentiment_scores_df = sentiment_scores_df.append({'Sentence': sentence, 'Compound Score': scores['compound'],
# C:\Users\hp\AppData\Local\Temp\ipykernel_10612\733496169.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sentiment_scores_df = sentiment_scores_df.append({'Sentence': sentence, 'Compound Score': scores['compound'],
# C:\Users\hp\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)
